# %%
# import job_analyzer

# job_analyzer.calculate_salary(100000)

# %%
# from job_analyzer import calculate_salary,calculate_bonus
# calculate_salary(100000)
# calculate_bonus(110000,100000)

# %%
# from job_analyzer import *
# calculate_salary(100000)
# calculate_bonus(110000,100000)

# %% [markdown]
# statistics module

# %%
salaryList=[98000,101000,102000,99000,97000]

# %%
import statistics as st
st.mean(salaryList)
# Out:
# 99400

# %%
from statistics import mean, mode , median
mean(salaryList)
# Out:
# 99400

# %%
mode(salaryList)
# Out:
# 98000

# %%
median(salaryList)
# Out:
# 99000

# %% [markdown]
# Exercise

# %%
dataScienceJob=[
    {'job_title':'Data Scientist','job_skills':"['Python','SQL','Machine Learning']",'job_date':'2023-05-12'},
    {'job_title':'Data Engineer','job_skills':"['AWS','Python','TensorFlow']",'job_date':'2023-05-18'},
    {'job_title':'Data Scientist','job_skills':"['Python','Data Analysis','SQL']",'job_date':'2023-05-06'},

]

# %%
from datetime import datetime, date

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 5, 10, 18, 46, 14, 381724)

# %%
dataScienceJob[0]['job_date']
# Out:
# '2023-05-12'

# %%
type(dataScienceJob[0]['job_date']  )
# Out:
# str

# %%
testDate=dataScienceJob[0]['job_date']

# %%
print(datetime.strptime(testDate,'%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
print(date.strftime(datetime.strptime(testDate,'%Y-%m-%d'),'%Y-%m-%d'))
# Out:
# 2023-05-12

# %%
help(datetime.strptime)
# Out:
# Help on built-in function strptime:
#
# strptime(...) class method of datetime.datetime
#     string, format -> new datetime parsed from a string (like time.strptime()).

# %%
help(date.strftime)
# Out:
# Help on method_descriptor:
#
# strftime(...) unbound datetime.date method
#     format -> strftime() style string.

# %%
dataScienceJob = [
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python','Scikit-learn','Pandas']", 'job_date': '2023-05-20'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel','SQL','Tableau']", 'job_date': '2023-05-22'},
    {'job_title': 'AI Researcher', 'job_skills': "['Deep Learning','Python','PyTorch']", 'job_date': '2023-05-25'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['Power BI','SQL','Data Visualization']", 'job_date': '2023-05-27'},
    {'job_title': 'Big Data Engineer', 'job_skills': "['Hadoop','Spark','Python']", 'job_date': '2023-06-01'},
    {'job_title': 'Data Scientist', 'job_skills': "['R','Machine Learning','Statistics']", 'job_date': '2023-06-03'},
    {'job_title': 'NLP Engineer', 'job_skills': "['NLP','SpaCy','Text Mining']", 'job_date': '2023-06-05'}
]

# %%
for job in dataScienceJob:
    job['job_date']=datetime.strptime(job['job_date'],'%Y-%m-%d')

# %%
dataScienceJob
# Out:
# [{'job_title': 'Machine Learning Engineer',
#   'job_skills': "['Python','Scikit-learn','Pandas']",
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['Excel','SQL','Tableau']",
#   'job_date': datetime.datetime(2023, 5, 22, 0, 0)},
#  {'job_title': 'AI Researcher',
#   'job_skills': "['Deep Learning','Python','PyTorch']",
#   'job_date': datetime.datetime(2023, 5, 25, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': "['Power BI','SQL','Data Visualization']",
#   'job_date': datetime.datetime(2023, 5, 27, 0, 0)},
#  {'job_title': 'Big Data Engineer',
#   'job_skills': "['Hadoop','Spark','Python']",
#   'job_date': datetime.datetime(2023, 6, 1, 0, 0)},
#  {'job_title': 'Data Scientist',
#   'job_skills': "['R','Machine Learning','Statistics']",
#   'job_date': datetime.datetime(2023, 6, 3, 0, 0)},
#  {'job_title': 'NLP Engineer',
#   'job_skills': "['NLP','SpaCy','Text Mining']",
# ...

# %%
#cleaning the skills into list

# %%
import ast

for job in dataScienceJob:
    job['job_skills']=ast.literal_eval(job['job_skills'])

# %%
type(dataScienceJob[0]['job_skills'])
# Out:
# list

# %%
dataScienceJob
# Out:
# [{'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'Scikit-learn', 'Pandas'],
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['Excel', 'SQL', 'Tableau'],
#   'job_date': datetime.datetime(2023, 5, 22, 0, 0)},
#  {'job_title': 'AI Researcher',
#   'job_skills': ['Deep Learning', 'Python', 'PyTorch'],
#   'job_date': datetime.datetime(2023, 5, 25, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': ['Power BI', 'SQL', 'Data Visualization'],
#   'job_date': datetime.datetime(2023, 5, 27, 0, 0)},
#  {'job_title': 'Big Data Engineer',
#   'job_skills': ['Hadoop', 'Spark', 'Python'],
#   'job_date': datetime.datetime(2023, 6, 1, 0, 0)},
#  {'job_title': 'Data Scientist',
#   'job_skills': ['R', 'Machine Learning', 'Statistics'],
#   'job_date': datetime.datetime(2023, 6, 3, 0, 0)},
#  {'job_title': 'NLP Engineer',
#   'job_skills': ['NLP', 'SpaCy', 'Text Mining'],
# ...

# %% [markdown]
# #library

# %%
file =open('sample_data/california_housing_test.csv')
content=file.read()
file.close()

# %%
import csv

data_dict={}
for index, row in enumerate(csv.reader(content.strip().split('\n'))):
  if index==0:
    for column in row:
      data_dict[column]=[]
  else:
    for col_index, value in enumerate(row):
      data_dict[list(data_dict.keys())[col_index].append(value)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-d95e1c49a142> in <cell line: 0>()
#       8   else:
#       9     for col_index, value in enumerate(row):
# ---> 10       data_dict[list(data_dict.keys())[col_index].append(value)]
#
# AttributeError: 'str' object has no attribute 'append'

# %%
#instead use

# %%
import pandas as pd
contents= pd.read_csv('sample_data/california_housing_test.csv')
contents['total_bedrooms']

# %%
contents['total_bedrooms'].sum()

# %%
sum(contents['total_bedrooms'])

# %%
#shell command

# %%
# !pip install pandas

# %%
# !pip list

# %%
# !pip install pyjokes # basically humare install krne wo environment mein aa jata  h but still we have to import it to use it

# %%
import pyjokes

# %%
pyjokes.get_joke()

# %%
pyjokes.get_joke()

# %% [markdown]
# #classes

# %%
class List:
    def __init__(self):
        """Initialize an empty list."""
        self._items = []

    def add(self, item):
        """Add an item to the end of the list."""
        self._items.append(item)

    def __getitem__(self, index):
        """Retrieve an item by index."""
        return self._items[index]

    def __setitem__(self, index, value):
        """Set an item at a specific index."""
        self._items[index] = value

    def __repr__(self):
        """Return a string representation of the list."""
        return str(self._items)

    def __len__(self):
        """Return the length of the list."""
        return len(self._items)

# %%
my_list = List()

# %%
my_list

# %%
my_list.add(10)

# %%
my_list.add('data nerds')

# %%
len(my_list)

# %%
help(List)

# %%
def calculate_salary(base_salary, bonus_rate=.1):
  """
  Calculate the total salary based on the base salary and bonus rate.

  Args:
    base_salary (float): The base salary.
    bonus_rate (float): The bonus rate. Default is .1.

  Returns:
    float: The total salary.
  """
  return base_salary * (1 + bonus_rate)

def calculate_bonus(total_salary, base_salary):
  """
  Calculate the bonus rate based on the total salary and base salary.

  Args:
    total_salary (float): The total salary.
    base_salary (float): The base salary.

  Returns:
    float: The bonus rate.
  """
  return (total_salary - base_salary)/base_salary

# %%
class BaseSalary:
  def __init__(self,base_salary,bonus_rate=0.1,symbol="$"):
    self.base_salary=base_salary
    self.bonus_rate=bonus_rate
    self.symbol=symbol
    self.total_salary= base_salary * (1 + bonus_rate)
    self.bonus=(self.total_salary - self.base_salary)

  def __repr__(self):
    return f"{self.symbol}{self.base_salary:,.0f}"

  def show_salary(self):
    return f"{self.symbol}{self.total_salary:,.0f}"


  def show_bonus(self):
    return f"{self.symbol}{self.bonus:,.0f}"

# %%
salary=BaseSalary(100000)
salary.base_salary
salary.bonus_rate
salary.symbol

# %%
salary

# %%
value=100000
f"{value}"

# %%
f'{value:,}'

# %%
f"{value:,.2f}"

# %%
#so#

# %%
salary.show_salary()

# %%
salary.show_bonus()

# %% [markdown]
# #numpy

# %%
#create a list of 1,000,000 salaries ranging from 50,000 to 150,000
import random
import statistics
salaries = [random.randint(50000,100000) for  _ in range(1_00_000)]

# %%
# magic commands
# %%timeit


# statistics.mean(salaries)
statistics.median(salaries)

# %%
import numpy as np

# %%
# %%timeit
# np.mean(salaries)
np.median(salaries)

# %%
import numpy as np

# %%
myArray=np.array([1,2,3,4])

# %%
myArray.mean()

# %%
job_titles=np.array(['data scientist','data engineer','data analyst','machine learning engineer','ai researcher'])

base_salaries=np.array([100000,150000,120000,200000,None])

bonus_rates=np.array([.1,.2,.15,.25,None])

# %%
np.mean(total_salaries)

# %%
np.nan

# %%
job_titles=np.array(['data scientist','data engineer','data analyst','machine learning engineer','ai researcher'])

base_salaries=np.array([100000,150000,120000,200000,np.nan])

bonus_rates=np.array([.1,.2,.15,.25,np.nan])

# %%
total_salaries=base_salaries*(1+bonus_rates)
total_salaries

# %%
np.mean(total_salaries)

# %%
np.nanmean(total_salaries)

# %% [markdown]
# #pandas

# %%
import pandas as pd

# %%
# !pip list

# %%
import pandas as pd
df=pd.read_csv('sample_data/california_housing_test.csv')

# %%
type(df)

# %%
df['total_bedrooms']

# %%
df.total_bedrooms

# %%
df.total_bedrooms[0]

# %%
df['total_bedrooms'][0]

# %%
#for getting the dataset from hugging face

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %%
from datasets import load_dataset

# %%
dataset=load_dataset('lukebarousse/data_jobs')

# %%
dataset['train']   #train is the key here

# %%
df=dataset['train'].to_pandas()

# %%
#pandas: inspection

# %%
import pandas as pd
from datasets import load_dataset

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

# %%
df

# %%
df.head()

# %%
df.head(10)

# %%
#head give the top rows
# tail gives you last rows
# default provide 5 values

# %%
df.tail()

# %%
df.tail(10)

# %%
df['job_title_short'].head(10)

# %%
df[['job_title_short','job_location']].head(100)                #to provide multiple different column

# %%
df.iloc[90]                    #purely integer -location based indexing for selecting by position

# %%
df.iloc[90:100]

# %%
df.iloc[90:100,0]    #second argument refers to column index

# %%
df.iloc[90:100,0:3]

# %%
df[['job_title_short','job_location']].iloc[90:100]

# %%
# df.info() get the key info on the dataset
# df.describe()-get key numerical statistics
# df['colmn name'].unique()=number of distinct values
# df.shape()=get the(rows, columns)
# len(df)=get the num of rows
# df.index-describe the index
# df.columns-get the columns names
# df.count()- num of non _NA values

# %%
df.info()

# %%
len(df)

# %%
df.shape

# %%
df.index

# %%
df.columns

# %%
df.count()

# %%
df.describe() # satistics for numerical column

# %%
df.job_title_short.unique()

# %%
df['job_title_short'].unique()

# %%
df[(df.job_title_short=='Data Analyst') & (df.salary_year_avg>100000)]

# %%
df.salary_year_avg.notna()

# %%
df[(df.job_title_short=='Data Analyst') & (df.salary_year_avg.notna())]

# %%
# pandas cleansing

# %%
import pandas as pd
from datasets import load_dataset

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

# %%
df.info()

# %%
df.job_posted_date[0]

# %%
type(df.job_posted_date[0] )

# %%
pd.to_datetime(df.job_posted_date)

# %%
df['job_posted_date']=pd.to_datetime(df.job_posted_date)

# %%
df.info()

# %%
df.job_posted_date.dt.month

# %%
df.job_posted_date

# %%
df['job_posted_month']=df.job_posted_date.dt.month

# %%
df.info()

# %%
df

# %%
#sorting

# %%
df.sort_values("job_posted_date")

# %%
df

# %%
df.sort_values(by="job_posted_date",inplace=True)

# %%
df

# %%
df.drop(labels='salary_hour_avg',axis=1, inplace=True)

# %%
df.info()

# %%
# droping column drop method we were using and now we are using dropna to drop specific columns

# %%
df.dropna(subset=['salary_year_avg'])         #subset takes in list of column you want to dropna from

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df.info()

# %%
#pandas analyzing

# %%
import pandas as pd
from datasets import load_dataset

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.count()
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
df['salary_year_avg'].idxmin()   # index value of min salary
# Out:
# 665729

# %%
min_salary=df['salary_year_avg'].idxmin()

# %%
df.iloc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short','job_country'])['salary_year_avg'].min()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      63000.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        28000.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg','salary_hour_avg']].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0        40.362499
# Cloud Engineer                     90000.0        40.000000
# Data Analyst                       90000.0        32.615002
# Data Engineer                     125000.0        58.500000
# Data Scientist                    127500.0        47.500000
# Machine Learning Engineer         106415.0        47.535000
# Senior Data Analyst               111175.0        47.500000
# Senior Data Engineer              147500.0        61.500000
# Senior Data Scientist             155500.0        47.620003
# Software Engineer                  99150.0        47.560001

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min','max','median'])
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['min'].plot(kind='hist', bins=20, title='min')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
#analyze salaries  exercise

# %%
import pandas as pd
from datasets import load_dataset

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['North Korea']).any()
# Out:
# np.False_

# %%
usa_jobs=df[df['job_country']=="United States"]

# %%
usa_jobs
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
usa_jobs=usa_jobs[usa_jobs['salary_year_avg'].notna()]
usa_jobs
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
usa_jobs.groupby('job_title_short').count()
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                 431           425      431
# Cloud Engineer                    20            20       20
# Data Analyst                    4350          4285     4350
# Data Engineer                   2915          2869     2915
# Data Scientist                  4553          4498     4553
# Machine Learning Engineer        128           128      128
# Senior Data Analyst              913           903      913
# Senior Data Engineer            1058          1041     1058
# Senior Data Scientist           1241          1220     1241
# Software Engineer                157           155      157
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                         430                 431
# Cloud Engineer                            19                  20
# Data Analyst                            4342                4350
# ...

# %%
usa_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median','min','max','count']).sort_values(by='median',ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      155000.0  55000.0  475000.0   1241
# Machine Learning Engineer  150000.0  44408.5  315000.0    128
# Senior Data Engineer       150000.0  45000.0  375000.0   1058
# Data Scientist             130000.0  30000.0  960000.0   4553
# Software Engineer          130000.0  48982.0  375000.0    157
# Data Engineer              125000.0  23496.0  525000.0   2915
# Cloud Engineer             116100.0  42000.0  221844.0     20
# Senior Data Analyst        110000.0  35360.0  425000.0    913
# Business Analyst            90000.0  35000.0  387460.0    431
# Data Analyst                90000.0  25000.0  375000.0   4350
